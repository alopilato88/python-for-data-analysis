# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alopilato88/python-for-data-analysis/blob/main/code/test-code.ipynb)

# %%
x = "abc"
print(x)
# Out:
# abc

# %%
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York",
}

print(person)
print(person["name"])

# %% [markdown]
# ## This a Markdown Test
#
# This is a test of markdown.
